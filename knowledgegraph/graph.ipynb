# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
DG = nx.DiGraph()
DG.add_weighted_edges_from([('Motor Oil', 'Various Substance', 0.5), ('Various Substance', 'Lubrication', 0.5)])
DG.out_degree(1, weight='weight')
DG.degree(1, weight='weight')
# list(DG.successors(1))
# list(DG.neighbors(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/dev/networkx/networkx/classes/graph.py:2010, in Graph.nbunch_iter.<locals>.bunch_iter(nlist, adj)
#    2009 try:
# -> 2010     for n in nlist:
#    2011         if n in adj:
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[8], line 3
#       1 DG = nx.DiGraph()
#       2 DG.add_weighted_edges_from([('Motor Oil', 'Various Substance', 0.5), ('Various Substance', 'Lubrication', 0.5)])
# ----> 3 DG.out_degree(1, weight='weight')
#       4 DG.degree(1, weight='weight')
#       5 # list(DG.successors(1))
#       6 # list(DG.neighbors(1))
#
# File ~/dev/networkx/networkx/classes/reportviews.py:436, in DiDegreeView.__call__(self, nbunch, weight)
#     434 except TypeError:
#     435     pass
# --> 436 return self.__class__(self._graph, nbunch, weight)
#
# File ~/dev/networkx/networkx/classes/reportviews.py:421, in DiDegreeView.__init__(self, G, nbunch, weight)
#     419 self._succ = G._succ if hasattr(G, "_succ") else G._adj
#     420 self._pred = G._pred if hasattr(G, "_pred") else G._adj
# --> 421 self._nodes = self._succ if nbunch is None else list(G.nbunch_iter(nbunch))
#     422 self._weight = weight
#
# File ~/dev/networkx/networkx/classes/graph.py:2025, in Graph.nbunch_iter.<locals>.bunch_iter(nlist, adj)
#    2021 if "hashable" in message:
#    2022     exc = NetworkXError(
#    2023         f"Node {n} in sequence nbunch is not a valid node."
#    2024     )
# -> 2025 raise exc
#
# NetworkXError: nbunch is not a node or a sequence of nodes.

# %%
nx.draw(DG, with_labels=True, font_weight='bold')
